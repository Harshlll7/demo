# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshlll7/demo/blob/main/Exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python program to add 2 **num**

# %%
a=2
b=3
add=a+b
print(add)
# Out:
# 5

# %% [markdown]
# # New section

# %% [markdown]
# Prgram to take user input and add 2 num

# %% [markdown]
# # Python calculator

# %%
num1 =int(input("Enter num1:"))
num2 =int(input("Enter num2:"))
add=num1+num2
sub=num1-num2
mul=num1*num2
div=num1/num2

print("1.Add")
print("2.Sub")
print("3.Mul")
print("4.Div")
choice=input("Enter your choice(1/2/3/4):")

if choice=='1':
  print(add)
elif choice=='2 ':
  print(sub)
elif choice=='3':
  print(mul)
elif choice=='4':
  print(div)
else:
  print("Invalid choice")
# Out:
# Enter num1:2
# Enter num2:3
# 1.Add
# 2.Sub
# 3.Mul
# 4.Div
# Enter your choice(1/2/3/4):1
# 5

# %% [markdown]
# # Python code for text handling

# %%
def is_palindrome(text):
    cleaned_text = ''.join(char.lower() for char in text if char.isalnum())
    return cleaned_text == cleaned_text[::-1]

user_input = input("Enter a string to check if it's a palindrome: ")

if is_palindrome(user_input):
    print(f"'{user_input}' is a palindrome!")
else:
    print(f"'{user_input}' is not a palindrome.")
# Out:
# Enter a string to check if it's a palindrome: Malayalam
# 'Malayalam' is a palindrome!
